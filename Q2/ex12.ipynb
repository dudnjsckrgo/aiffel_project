# %% [markdown]
# - 데이터 탐색
#  - 문제 정의
#  - 변수 설명
#  - 시각화
#  - 이상치 및 결측치 확인
#  - 유니크 갯수
# - 데이터 전처리
#  - 이상치 및 결측치 처리
#  - 정규화
# - 변수 생성
# - 모델링
# - GBM

# %%
# 패키지 임포트
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import gc

# %%
df_train = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (15035, 21)
# (6468, 20)

# %%
df_train.head(20)
# Out:
#     id             date      price  bedrooms  bathrooms  sqft_living  \
# 0    0  20141013T000000   221900.0         3       1.00         1180
# 1    1  20150225T000000   180000.0         2       1.00          770
# 2    2  20150218T000000   510000.0         3       2.00         1680
# 3    3  20140627T000000   257500.0         3       2.25         1715
# 4    4  20150115T000000   291850.0         3       1.50         1060
# 5    5  20150403T000000   662500.0         3       2.50         3560
# 6    6  20140527T000000   468000.0         2       1.00         1160
# 7    7  20140528T000000   310000.0         3       1.00         1430
# 8    8  20141007T000000   400000.0         3       1.75         1370
# 9    9  20150312T000000   530000.0         5       2.00         1810
# 10  10  20150124T000000   650000.0         4       3.00         2950
# 11  11  20140731T000000   395000.0         3       2.00         1890
# 12  12  20140529T000000   485000.0         4       1.00         1600
# 13  13  20141205T000000   189000.0         2       1.00         1200
# 14  14  20150424T000000   230000.0         3       1.00         1250
# 15  15  20140514T000000   385000.0         4       1.75         1620
# 16  16  20140826T000000  2000000.0         3       2.75         3050
# 17  17  20140516T000000   252700.0         2       1.50         1070
# 18  18  20141120T000000   329000.0         3       2.25         2450
# 19  19  20141103T000000   233000.0         3       2.00         1710
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0       5650     1.0           0     0  ...      7        1180              0
# 1      10000     1.0           0     0  ...      6         770              0
# 2       8080     1.0           0     0  ...      8        1680              0
# 3       6819     2.0           0     0  ...      7        1715              0
# 4       9711     1.0           0     0  ...      7        1060              0
# 5       9796     1.0           0     0  ...      8        1860           1700
# 6       6000     1.0           0     0  ...      7         860            300
# 7      19901     1.5           0     0  ...      7        1430              0
# 8       9680     1.0           0     0  ...      7        1370              0
# 9       4850     1.5           0     0  ...      7        1810              0
# 10      5000     2.0           0     3  ...      9        1980            970
# 11     14040     2.0           0     0  ...      7        1890              0
# 12      4300     1.5           0     0  ...      7        1600              0
# 13      9850     1.0           0     0  ...      7        1200              0
# 14      9774     1.0           0     0  ...      7        1250              0
# 15      4980     1.0           0     0  ...      7         860            760
# 16     44867     1.0           0     4  ...      9        2330            720
# 17      9643     1.0           0     0  ...      7        1070              0
# 18      6500     2.0           0     0  ...      8        2450              0
# 19      4697     1.5           0     0  ...      6        1710              0
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0       1955             0    98178  47.5112 -122.257           1340
# 1       1933             0    98028  47.7379 -122.233           2720
# 2       1987             0    98074  47.6168 -122.045           1800
# 3       1995             0    98003  47.3097 -122.327           2238
# 4       1963             0    98198  47.4095 -122.315           1650
# 5       1965             0    98007  47.6007 -122.145           2210
# 6       1942             0    98115  47.6900 -122.292           1330
# 7       1927             0    98028  47.7558 -122.229           1780
# 8       1977             0    98074  47.6127 -122.045           1370
# 9       1900             0    98107  47.6700 -122.394           1360
# 10      1979             0    98126  47.5714 -122.375           2140
# 11      1994             0    98019  47.7277 -121.962           1890
# 12      1916             0    98103  47.6648 -122.343           1610
# 13      1921             0    98002  47.3089 -122.210           1060
# 14      1969             0    98003  47.3343 -122.306           1280
# 15      1947             0    98133  47.7025 -122.341           1400
# 16      1968             0    98040  47.5316 -122.233           4110
# 17      1985             0    98030  47.3533 -122.166           1220
# 18      1985             0    98030  47.3739 -122.172           2200
# 19      1941             0    98002  47.3048 -122.218           1030
#
#     sqft_lot15
# 0         5650
# 1         8062
# 2         7503
# 3         6819
# 4         9711
# 5         8925
# 6         6000
# 7        12697
# 8        10208
# 9         4850
# 10        4000
# 11       14018
# 12        4300
# 13        5095
# 14        8850
# 15        4980
# 16       20336
# 17        8386
# 18        6865
# 19        4705
#
# [20 rows x 21 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15035 entries, 0 to 15034
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             15035 non-null  int64
#  1   date           15035 non-null  object
#  2   price          15035 non-null  float64
#  3   bedrooms       15035 non-null  int64
#  4   bathrooms      15035 non-null  float64
#  5   sqft_living    15035 non-null  int64
#  6   sqft_lot       15035 non-null  int64
#  7   floors         15035 non-null  float64
#  8   waterfront     15035 non-null  int64
#  9   view           15035 non-null  int64
#  10  condition      15035 non-null  int64
#  11  grade          15035 non-null  int64
#  12  sqft_above     15035 non-null  int64
#  13  sqft_basement  15035 non-null  int64
#  14  yr_built       15035 non-null  int64
#  15  yr_renovated   15035 non-null  int64
#  16  zipcode        15035 non-null  int64
#  17  lat            15035 non-null  float64
#  18  long           15035 non-null  float64
#  19  sqft_living15  15035 non-null  int64
#  20  sqft_lot15     15035 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 2.4+ MB

# %%
# 요약
df_train['price'].describe()
# Out:
# count    1.503500e+04
# mean     5.406827e+05
# std      3.715247e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
# 가격 히스토그램
plt.figure(figsize=(8,6))
sns.histplot(df_train['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
print('Skewness:', df_train['price'].skew())
print('Kurtosis:', df_train['price'].kurt())
# Out:
# Skewness: 4.290252396939529
# Kurtosis: 40.15491919350329

# %% [markdown]
# - 왜도(skewness) : 데이터 분포가 얼마나 치우쳤는지 보여주는 척도로서, 왼쪽으로 꼬리가 길수록 음수 방향으로 값이 커지고, 오른쪽으로 꼬리가 길수록 양수 방향으로 값이 커진다.
# - 첨도(kurtosis) : 데이터 분포가 분포 가운데에 얼마나 몰려있는지 보여주는 척도로서, 첨도 값(K)이 3에 가까울 경우 그래프는 정규분포에 가깝고, (K<3)이면 정규분포보다 더 평탄하다고 판단할 수 있으며, (K>3)인 경우 정규분포보다 더 뾰족한 분포로 간주 할 수 있다.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
fig.set_size_inches(10,8)
stats.probplot(x=df_train['price'], plot=axes[0])
stats.probplot(x=np.log1p(df_train['price']), plot=axes[1])
# Out:
# ((array([-3.91024552, -3.69050911, -3.57011438, ...,  3.57011438,
#           3.69050911,  3.91024552]),
#   array([11.26447693, 11.28979441, 11.30221678, ..., 15.74485584,
#          15.7703098 , 15.85673102])),
#  (0.5246386762816584, 13.04812230186611, 0.9944175231748045))

# %%
df_train['price'] = np.log1p(df_train['price'])

# %% [markdown]
# # 가격에 관한 상관관계
# k = 15 # 히트맵에 표시할 변수 갯수
# corrmat = abs(df_train.corr(method='spearman')) # correlation 전체 변수에 대해서 계산
# cols = corrmat.nlargest(k, 'price').index # nlargest : return this many descending sorted values
# cm = np.corrcoef(df_train[cols].values.T) # correlation 특정 칼럼에 대해서
#
# fig, ax = plt.subplots(figsize=(18,8))
# sns.heatmap(data=cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':8}, yticklabels=cols.values, xticklabels=cols.values, ax=ax)

# %%
data = pd.concat([df_train['price'], df_train['grade']], axis=1)
f, ax = plt.subplots(figsize=(10,8))
sns.boxplot(data=data, x='grade', y='price', ax=ax)
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
data = pd.concat([df_train['sqft_living'], df_train['price']], axis=1)
f, ax = plt.subplots(figsize=(10,8))
sns.regplot(x='sqft_living', y='price', data=data, ax=ax)
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
data = pd.concat([df_train['sqft_living15'], df_train['price']], axis=1)
f, ax = plt.subplots(figsize=(10,8))
sns.regplot(x='sqft_living15', y='price', data=data, ax=ax)
# Out:
# <Axes: xlabel='sqft_living15', ylabel='price'>

# %%
sns.histplot(df_train['sqft_living15'])
# Out:
# <Axes: xlabel='sqft_living15', ylabel='Count'>

# %%
data = pd.concat([df_train['sqft_above'], df_train['price']], axis=1)
f, ax = plt.subplots(figsize=(10,8))
sns.regplot(x='sqft_above', y='price', data=data)
# Out:
# <Axes: xlabel='sqft_above', ylabel='price'>

# %%
data = pd.concat([df_train['bedrooms'], df_train['price']], axis=1)
f, ac = plt.subplots(figsize=(12,8))
sns.boxplot(x='bedrooms', y='price', data=data)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,8))
ax[0].set(title='Train set')
sns.countplot(x='bedrooms', data=df_train, ax=ax[0])

ax[1].set(title='Test set')
sns.countplot(x='bedrooms', data=df_test, ax=ax[1])
# Out:
# <Axes: title={'center': 'Test set'}, xlabel='bedrooms', ylabel='count'>

# %%
data = pd.concat([df_train['bathrooms'], df_train['price']], axis=1)
f, ac = plt.subplots(figsize=(15,8))
sns.boxplot(x='bathrooms', y='price', data=data, palette=sns.color_palette('pastel'))
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(20,8))
ax[0].set(title='Train set')
sns.countplot(x='bathrooms', data=df_train, ax=ax[0])

ax[1].set(title='Test set')
sns.countplot(x='bathrooms', data=df_test, ax=ax[1])
# Out:
# <Axes: title={'center': 'Test set'}, xlabel='bathrooms', ylabel='count'>

# %% [markdown]
# ## 이상치 제거

# %%
data = pd.concat([df_train['price'], df_train['grade']], axis=1)
f, ax = plt.subplots(figsize=(10,8))
sns.boxplot(data=data, x='grade', y='price', ax=ax)
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
df_train.loc[(df_train['price']>14.5) & (df_train['grade']==7)]
# Out:
#           id             date      price  bedrooms  bathrooms  sqft_living  \
# 12346  12346  20150115T000000  14.533351         4       3.25         3580
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 12346     19989     1.5           1     4  ...      7        3480
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 12346            100      1915          1965    98125  47.7087 -122.276
#
#        sqft_living15  sqft_lot15
# 12346           2410        6389
#
# [1 rows x 21 columns]

# %%
df_train.loc[(df_train['price']>14.7) & (df_train['grade']==8)]
# Out:
#         id             date      price  bedrooms  bathrooms  sqft_living  \
# 7173  7173  20140813T000000  14.808763         5        4.0         4230
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7173     27295     2.0           1     4  ...      8        3230
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7173           1000      1949          1985    98033  47.6803 -122.214
#
#       sqft_living15  sqft_lot15
# 7173           2660       27295
#
# [1 rows x 21 columns]

# %%
df_train.loc[(df_train['price']>15.5) & (df_train['grade']==11)]
# Out:
#         id             date     price  bedrooms  bathrooms  sqft_living  \
# 2775  2775  20140611T000000  15.77031         5        4.5        10040
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 2775     37325     2.0           1     2  ...     11        7680
#
#       sqft_basement  yr_built  yr_renovated  zipcode    lat     long  \
# 2775           2360      1940          2001    98004  47.65 -122.214
#
#       sqft_living15  sqft_lot15
# 2775           3930       25449
#
# [1 rows x 21 columns]

# %%
df_train = df_train.loc[df_train['id'] != 2775]
df_train = df_train.loc[df_train['id'] != 7173]
df_train = df_train.loc[df_train['id'] != 12346]

# %% [markdown]
# ## 정규화
# baseline을 활용해 편향된 데이터들을 정규화 해주겠습니다

# %%
skew_columns = ['sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement']
skew_columns2 = ['sqft_living15', 'sqft_lot15'] # 1/3 제곱시켜 정규분포에 가깝게!



# for c in skew_columns:
#     df_train[c] = np.log1p(df_train[c].values)
#     df_test[c] = np.log1p(df_test[c].values)
    
# for c in skew_columns2:
#     df_train[c] = np.power(df_train[c].values, 1/3)
#     df_test[c] = np.power(df_test[c].values, 1/3)

# %% [markdown]
# ## 변수 수정

# %%
for df in [df_train, df_test]:
    df['date'] = df['date'].apply(lambda x: x[0:8])
    df['yr_renovated'] = df['yr_renovated'].apply(lambda x: np.nan if x == 0 else x)
    df['yr_renovated'] = df['yr_renovated'].fillna(df['yr_built'])

# %% [markdown]
# ## 변수 생성

# %%
df_train.head()
# Out:
#    id      date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0   0  20141013  12.309987         3       1.00         1180      5650
# 1   1  20150225  12.100718         2       1.00          770     10000
# 2   2  20150218  13.142168         3       2.00         1680      8080
# 3   3  20140627  12.458779         3       2.25         1715      6819
# 4   4  20150115  12.583999         3       1.50         1060      9711
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     1.0           0     0  ...      6         770              0      1933
# 2     1.0           0     0  ...      8        1680              0      1987
# 3     2.0           0     0  ...      7        1715              0      1995
# 4     1.0           0     0  ...      7        1060              0      1963
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0        1955.0    98178  47.5112 -122.257           1340        5650
# 1        1933.0    98028  47.7379 -122.233           2720        8062
# 2        1987.0    98074  47.6168 -122.045           1800        7503
# 3        1995.0    98003  47.3097 -122.327           2238        6819
# 4        1963.0    98198  47.4095 -122.315           1650        9711
#
# [5 rows x 21 columns]

# %%
for df in [df_train, df_test]:
    df['total_rooms'] = df['bedrooms'] + df['bathrooms']
    # 거실의 비율
    df['sqft_ratio'] = df['sqft_living'] / df['sqft_lot']
    # 총 면적
    df['sqft_total_size'] = df['sqft_living'] + df['sqft_lot'] + df['sqft_above'] + df['sqft_basement']
    # 면적 대비 거실 비율
#     df['sqft_ratio_1'] = df['sqft_living'] / df['sqft_total_size']
    df['sqft_total15'] = df['sqft_living15'] + df['sqft_lot15']
#     df['sqft_ratio15'] = df['sqft_living15'] / df['sqft_total15'] 

    df['is_renovated'] = df['yr_renovated'] - df['yr_built']
    df['is_renovated'] = df['is_renovated'].apply(lambda x: 0 if x==0 else 1)
    df['date'] = df['date'].astype('int')

# %%
df_train['per_price'] = df_train['price'] / df_train['sqft_total_size']

# %%
df_train
# Out:
#           id      date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0          0  20141013  12.309987         3       1.00         1180      5650
# 1          1  20150225  12.100718         2       1.00          770     10000
# 2          2  20150218  13.142168         3       2.00         1680      8080
# 3          3  20140627  12.458779         3       2.25         1715      6819
# 4          4  20150115  12.583999         3       1.50         1060      9711
# ...      ...       ...        ...       ...        ...          ...       ...
# 15030  15030  20141014  13.322338         4       2.50         2520      6023
# 15031  15031  20150326  13.822984         4       3.50         3510      7200
# 15032  15032  20140521  12.793862         3       2.50         1530      1131
# 15033  15033  20150223  12.899222         4       2.50         2310      5813
# 15034  15034  20141015  12.691584         2       0.75         1020      1076
#
#        floors  waterfront  view  ...      lat     long  sqft_living15  \
# 0         1.0           0     0  ...  47.5112 -122.257           1340
# 1         1.0           0     0  ...  47.7379 -122.233           2720
# 2         1.0           0     0  ...  47.6168 -122.045           1800
# 3         2.0           0     0  ...  47.3097 -122.327           2238
# 4         1.0           0     0  ...  47.4095 -122.315           1650
# ...       ...         ...   ...  ...      ...      ...            ...
# 15030     2.0           0     0  ...  47.5137 -122.167           2520
# 15031     2.0           0     0  ...  47.5537 -122.398           2050
# 15032     3.0           0     0  ...  47.6993 -122.346           1530
# 15033     2.0           0     0  ...  47.5107 -122.362           1830
# 15034     2.0           0     0  ...  47.5941 -122.299           1020
#
#        sqft_lot15  total_rooms  sqft_ratio  sqft_total_size  sqft_total15  \
# 0            5650         4.00    0.208850             8010          6990
# 1            8062         3.00    0.077000            11540         10782
# 2            7503         5.00    0.207921            11440          9303
# 3            6819         5.25    0.251503            10249          9057
# 4            9711         4.50    0.109155            11831         11361
# ...           ...          ...         ...              ...           ...
# 15030        6023         6.50    0.418396            11063          8543
# 15031        6200         7.50    0.487500            14220          8250
# 15032        1509         5.50    1.352785             4191          3039
# 15033        7200         6.50    0.397385            10433          9030
# 15034        1357         2.75    0.947955             3116          2377
#
#        is_renovated  per_price
# 0                 0   0.001537
# 1                 0   0.001049
# 2                 0   0.001149
# 3                 0   0.001216
# 4                 0   0.001064
# ...             ...        ...
# 15030             0   0.001204
# 15031             0   0.000972
# 15032             0   0.003053
# 15033             0   0.001236
# 15034             0   0.004073
#
# [15032 rows x 27 columns]

# %%
zipcode_price = df_train.groupby(['zipcode'])['per_price'].agg({'mean', 'var'}).reset_index()
zipcode_price
# Out:
#     zipcode           var      mean
# 0     98001  1.430020e-07  0.000954
# 1     98002  1.204213e-07  0.001251
# 2     98003  1.086031e-07  0.000994
# 3     98004  1.505033e-07  0.000857
# 4     98005  1.139600e-07  0.000740
# ..      ...           ...       ...
# 65    98177  1.991216e-07  0.001002
# 66    98178  1.170809e-07  0.001189
# 67    98188  5.674163e-08  0.000989
# 68    98198  2.155114e-07  0.001103
# 69    98199  5.276832e-07  0.001619
#
# [70 rows x 3 columns]

# %%
df_train = pd.merge(df_train, zipcode_price, how='left', on='zipcode')
df_test = pd.merge(df_test, zipcode_price, how='left', on='zipcode')
df_train
# Out:
#           id      date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0          0  20141013  12.309987         3       1.00         1180      5650
# 1          1  20150225  12.100718         2       1.00          770     10000
# 2          2  20150218  13.142168         3       2.00         1680      8080
# 3          3  20140627  12.458779         3       2.25         1715      6819
# 4          4  20150115  12.583999         3       1.50         1060      9711
# ...      ...       ...        ...       ...        ...          ...       ...
# 15027  15030  20141014  13.322338         4       2.50         2520      6023
# 15028  15031  20150326  13.822984         4       3.50         3510      7200
# 15029  15032  20140521  12.793862         3       2.50         1530      1131
# 15030  15033  20150223  12.899222         4       2.50         2310      5813
# 15031  15034  20141015  12.691584         2       0.75         1020      1076
#
#        floors  waterfront  view  ...  sqft_living15  sqft_lot15  total_rooms  \
# 0         1.0           0     0  ...           1340        5650         4.00
# 1         1.0           0     0  ...           2720        8062         3.00
# 2         1.0           0     0  ...           1800        7503         5.00
# 3         2.0           0     0  ...           2238        6819         5.25
# 4         1.0           0     0  ...           1650        9711         4.50
# ...       ...         ...   ...  ...            ...         ...          ...
# 15027     2.0           0     0  ...           2520        6023         6.50
# 15028     2.0           0     0  ...           2050        6200         7.50
# 15029     3.0           0     0  ...           1530        1509         5.50
# 15030     2.0           0     0  ...           1830        7200         6.50
# 15031     2.0           0     0  ...           1020        1357         2.75
#
#        sqft_ratio  sqft_total_size  sqft_total15  is_renovated  per_price  \
# 0        0.208850             8010          6990             0   0.001537
# 1        0.077000            11540         10782             0   0.001049
# 2        0.207921            11440          9303             0   0.001149
# 3        0.251503            10249          9057             0   0.001216
# 4        0.109155            11831         11361             0   0.001064
# ...           ...              ...           ...           ...        ...
# 15027    0.418396            11063          8543             0   0.001204
# 15028    0.487500            14220          8250             0   0.000972
# 15029    1.352785             4191          3039             0   0.003053
# 15030    0.397385            10433          9030             0   0.001236
# 15031    0.947955             3116          2377             0   0.004073
#
#                 var      mean
# 0      1.170809e-07  0.001189
# 1      2.642196e-07  0.001026
# 2      8.766355e-08  0.000876
# 3      1.086031e-07  0.000994
# 4      2.155114e-07  0.001103
# ...             ...       ...
# 15027  1.238466e-07  0.001134
# 15028  7.491423e-07  0.001730
# 15029  7.193597e-07  0.002270
# 15030  1.297909e-07  0.001179
# 15031  1.063776e-06  0.002128
#
# [15032 rows x 29 columns]

# %%
del df_train['per_price']

# %% [markdown]
# 4. 모델링

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import make_pipeline

# %%
y_reg = df_train['price']
del df_train['price']
del df_train['id']
test_id = df_test['id']
del df_test['id']

# %%
kfolds = KFold(n_splits=10, random_state=2019, shuffle=True)

def cv_rmse(model):
    rmse = np.sqrt(-cross_val_score(estimator=model, X=df_train, y=y_reg, scoring='neg_mean_squared_error', cv=kfolds))
    return rmse

# %%
train_columns = [c for c in df_train.columns if c not in ['id']]

# %%
from sklearn.preprocessing import QuantileTransformer,PowerTransformer
quantile = QuantileTransformer(n_quantiles=100,random_state=42, output_distribution='normal')
q_scaled = quantile.fit_transform(df_train)
df_train = pd.DataFrame(q_scaled,columns=df_train.columns.tolist())
print(df_train.columns)
t_scaled = quantile.fit_transform(df_test)
df_test = pd.DataFrame(t_scaled,columns=df_test.columns.tolist())
print(df_test.columns)

from sklearn.preprocessing import StandardScaler
std = StandardScaler()
std.fit(df_train)
df_train_scaled = std.transform(df_train)
df_test_scaled = std.transform(df_test)
df_train = pd.DataFrame(df_train_scaled,columns=df_train.columns.tolist())

df_test = pd.DataFrame(df_test_scaled,columns=df_test.columns.tolist())
# Out:
# Index(['date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'total_rooms', 'sqft_ratio',
#        'sqft_total_size', 'sqft_total15', 'is_renovated', 'var', 'mean'],
#       dtype='object')
# Index(['date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'total_rooms', 'sqft_ratio',
#        'sqft_total_size', 'sqft_total15', 'is_renovated', 'var', 'mean'],
#       dtype='object')

# %%
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error

# 파라미터 그리드 정의
param_grid = {
"num_leaves":[20,25,30],
"learning_rate" : [0.1],
'n_estimators': [350,400],
'max_depth': [8,12],
"boosting_type":['gbdt'],
"feature_fraction":[0.5],
}


# 모델 정의
model = LGBMRegressor(objective='regression', max_depth=-1, random_state=2019, n_estimators=10000, n_jobs=-1)

# 그리드 서치 객체 생성
grid = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# 훈련 데이터 준비
X_train = df_train[train_columns]
y_train = y_reg

# 그리드 서치 실행
grid.fit(X_train, y_train)

# 결과 확인
print(f'Best parameters: {grid.best_params_}')
print(f'Best score (RMSE): {np.sqrt(-grid.best_score_)}')

# 최적의 파라미터를 사용한 모델 훈련
best_params = grid.best_params_
model.set_params(**best_params)
model.fit(X_train, y_train)

# 예측 및 성능 평가 (예시)
predictions = model.predict(df_test[train_columns])
# RMSE 계산
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000910 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3567
# [LightGBM] [Info] Number of data points in the train set: 15032, number of used features: 26
# [LightGBM] [Info] Start training from score 13.047725
# Best parameters: {'boosting_type': 'gbdt', 'feature_fraction': 0.5, 'learning_rate': 0.1, 'max_depth': 12, 'n_estimators': 400, 'num_leaves': 20}
# Best score (RMSE): 0.1602402665428964
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000887 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3567
# [LightGBM] [Info] Number of data points in the train set: 15032, number of used features: 26
# [LightGBM] [Info] Start training from score 13.047725
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5

# %%
params = grid.cv_results_['params']
score = grid.cv_results_['mean_test_score']

results = pd.DataFrame(params)
results['score'] = score

results['RMSLE'] = np.sqrt(-1 * results['score'])
results = results.sort_values('RMSLE')
results
# Out:
#    boosting_type  feature_fraction  learning_rate  max_depth  n_estimators  \
# 9           gbdt               0.5            0.1         12           400
# 6           gbdt               0.5            0.1         12           350
# 3           gbdt               0.5            0.1          8           400
# 1           gbdt               0.5            0.1          8           350
# 0           gbdt               0.5            0.1          8           350
# 10          gbdt               0.5            0.1         12           400
# 4           gbdt               0.5            0.1          8           400
# 7           gbdt               0.5            0.1         12           350
# 8           gbdt               0.5            0.1         12           350
# 2           gbdt               0.5            0.1          8           350
# 11          gbdt               0.5            0.1         12           400
# 5           gbdt               0.5            0.1          8           400
#
#     num_leaves     score     RMSLE
# 9           20 -0.025677  0.160240
# 6           20 -0.025717  0.160367
# 3           20 -0.025757  0.160489
# 1           25 -0.025775  0.160545
# 0           20 -0.025793  0.160602
# 10          25 -0.025795  0.160607
# 4           25 -0.025816  0.160674
# 7           25 -0.025824  0.160699
# 8           30 -0.025854  0.160793
# 2           30 -0.025885  0.160889
# 11          30 -0.025895  0.160919
# 5           30 -0.025942  0.161064

# %%
df_test[train_columns].shape
# Out:
# (6468, 26)

# %%
predictions
# Out:
# array([13.19669987, 13.00805805, 14.11878363, ..., 12.99583526,
#        12.67520472, 12.99818351])

# %%
test_preds = np.expm1(predictions)

# %%
submission0 = pd.DataFrame({'id' : test_id, 'price' : test_preds})
submission0.to_csv('lgbm.csv', index=False)

# %%
results = pd.DataFrame(grid.cv_results_)

# 관심 있는 컬럼 선택 (예: 파라미터와 테스트 점수)
columns_of_interest = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
results_filtered = results[columns_of_interest]

# 성능 점수(mean_test_score)에 따라 내림차순으로 정렬
results_sorted = results_filtered.sort_values(by='mean_test_score', ascending=False)
results_sorted
# Out:
#                                                params  mean_test_score  \
# 9   {'boosting_type': 'gbdt', 'feature_fraction': ...        -0.025677
# 6   {'boosting_type': 'gbdt', 'feature_fraction': ...        -0.025717
# 3   {'boosting_type': 'gbdt', 'feature_fraction': ...        -0.025757
# 1   {'boosting_type': 'gbdt', 'feature_fraction': ...        -0.025775
# 0   {'boosting_type': 'gbdt', 'feature_fraction': ...        -0.025793
# 10  {'boosting_type': 'gbdt', 'feature_fraction': ...        -0.025795
# 4   {'boosting_type': 'gbdt', 'feature_fraction': ...        -0.025816
# 7   {'boosting_type': 'gbdt', 'feature_fraction': ...        -0.025824
# 8   {'boosting_type': 'gbdt', 'feature_fraction': ...        -0.025854
# 2   {'boosting_type': 'gbdt', 'feature_fraction': ...        -0.025885
# 11  {'boosting_type': 'gbdt', 'feature_fraction': ...        -0.025895
# 5   {'boosting_type': 'gbdt', 'feature_fraction': ...        -0.025942
#
#     std_test_score  rank_test_score
# 9         0.001679                1
# 6         0.001669                2
# 3         0.001708                3
# 1         0.001787                4
# 0         0.001732                5
# 10        0.001770                6
# 4         0.001777                7
# 7         0.001765                8
# 8         0.001669                9
# 2         0.001511               10
# 11        0.001707               11
# 5         0.001533               12

# %%
# RMSE 계산
rmse = np.sqrt(mean_squared_error(y_reg, predictions))

# RMSE 출력
print(f'Test RMSE: {rmse}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\dudnj\ws\aiffel\ex1.ipynb Cell 55 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y105sZmlsZQ%3D%3D?line=0'>1</a> # RMSE 계산
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y105sZmlsZQ%3D%3D?line=1'>2</a> rmse = np.sqrt(mean_squared_error(y_reg, predictions))
#       <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y105sZmlsZQ%3D%3D?line=3'>4</a> # RMSE 출력
#       <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y105sZmlsZQ%3D%3D?line=4'>5</a> print(f'Test RMSE: {rmse}')
#
# File c:\Users\dudnj\.conda\envs\aiffel\lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File c:\Users\dudnj\.conda\envs\aiffel\lib\site-packages\sklearn\metrics\_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File c:\Users\dudnj\.conda\envs\aiffel\lib\site-packages\sklearn\metrics\_regression.py:99, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      65 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      66     """Check that y_true and y_pred belong to the same regression task.
#      67
#      68     Parameters
#    (...)
#      97         correct keyword.
#      98     """
# ---> 99     check_consistent_length(y_true, y_pred)
#     100     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File c:\Users\dudnj\.conda\envs\aiffel\lib\site-packages\sklearn\utils\validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [15032, 6468]

# %%
import lightgbm as lgb

param = {
    'num_leaves' : 31,
    'min_data_in_leaf' : 10,
    'objective' : 'regression',
    'max_depth' : -1,
    'learning_rate' : 0.008,
    'min_child_samples' : 12,
    'boosting' : 'gbdt',
    'feature_fraction' : 0.3,
    'bagging_freq' : 1,
    'bagging_fraction' : 0.6,
    'bagging_seed' : 11,
    'metric' : 'rmse',
    'lambda_l2' : 8,
    'verbosity' : -1,
    'nthread' : -1,
    'random_state' : 2019
}

# prepare fit model with cross-validation
folds = KFold(n_splits=5, shuffle=True, random_state=2019)
oof1 = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

# run model
for fold_, (trn_index, val_index) in enumerate(folds.split(df_train)):
    trn_data = lgb.Dataset(df_train.iloc[trn_index][train_columns], label=y_reg.iloc[trn_index])
    val_data = lgb.Dataset(df_train.iloc[val_index][train_columns], label=y_reg.iloc[val_index])
    
    num_round = 10000
    clf = lgb.train(params=param, train_set=trn_data, num_boost_round=num_round, valid_sets=[trn_data, val_data])
    oof1[val_index] = clf.predict(df_train.iloc[val_index][train_columns], num_iterations=clf.best_iteration) # 나중에 스태킹을 위한 train 데이터도 된다.
    # feature importance
    fold_importance_df = pd.DataFrame()
    fold_importance_df['Feature'] = train_columns
    fold_importance_df['importance'] = clf.feature_importance()
    
    fold_importance_df['fold'] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    # predictions
    predictions += clf.predict(df_test[train_columns], num_iterations=clf.best_iteration) / folds.n_splits # 나중에 스태킹을 위한 test 데이터도 된다.
    
cv = np.sqrt(mean_squared_error(oof1, y_reg))
print(cv)
# Out:
# 0.15855223717604178

# %%
test_lgb_preds = np.expm1(predictions)

# %%
submission0 = pd.DataFrame({'id' : test_id, 'price' : test_lgb_preds})
submission0.to_csv('lgb.csv', index=False)

# %%
import xgboost as xgb

params = {
    'booster' : 'gbtree',
    'max_depth': 7,
    'eta' : 0.008,
    'objective' : 'reg:linear',
    'eval_metric' : 'rmse',
    'n_thread' : -1,
    'silent' : 1,
    'lambda' : 8,
    'sub_sample' : 0.5,
    'random_state' : 2019
}

# prepare fit model with cross-validation
oof2 = np.zeros(len(df_train))
predictions2 = np.zeros((len(df_test)))
feature_importance_df2 = pd.DataFrame()

num_rounds = 10000
for folds_, (trn_index, val_index) in enumerate(folds.split(df_train)):
    trn_dmtx = xgb.DMatrix(data=df_train.iloc[trn_index][train_columns].values, label=y_reg.iloc[trn_index].values)
    val_dmtx = xgb.DMatrix(data=df_train.iloc[val_index][train_columns].values, label=y_reg.iloc[val_index].values)
    
    wlist = [(trn_dmtx, 'train'),(val_dmtx, 'eval')]
    clf = xgb.train(params=params, dtrain=trn_dmtx, num_boost_round=num_rounds, evals=wlist, verbose_eval=100, early_stopping_rounds=100)
    oof2[val_index] = clf.predict(data=val_dmtx) # 스태킹 모델링을 위해 남겨놓는다(스태킹 모델의 훈련 데이터)
    
    # 스테킹 모델의 테스트 데이터가 된다.
    predictions2 += clf.predict(data=xgb.DMatrix(data=df_test[train_columns].values)) / folds.n_splits
    
cv = np.sqrt(mean_squared_error(oof2, y_reg))
print(cv)
# Out:
# [0]	train-rmse:0.52475	eval-rmse:0.51789
# [100]	train-rmse:0.30127	eval-rmse:0.30820
# [200]	train-rmse:0.20674	eval-rmse:0.22541
# [300]	train-rmse:0.16725	eval-rmse:0.19439
# [400]	train-rmse:0.14876	eval-rmse:0.18112
# [500]	train-rmse:0.13906	eval-rmse:0.17446
# [600]	train-rmse:0.13347	eval-rmse:0.17078
# [700]	train-rmse:0.13017	eval-rmse:0.16875
# [800]	train-rmse:0.12723	eval-rmse:0.16713
# [900]	train-rmse:0.12457	eval-rmse:0.16585
# [1000]	train-rmse:0.12241	eval-rmse:0.16500
# [1100]	train-rmse:0.12022	eval-rmse:0.16429
# [1200]	train-rmse:0.11821	eval-rmse:0.16365
# [1300]	train-rmse:0.11654	eval-rmse:0.16328
# [1400]	train-rmse:0.11476	eval-rmse:0.16300
# [1500]	train-rmse:0.11333	eval-rmse:0.16271
# [1600]	train-rmse:0.11205	eval-rmse:0.16244
# [1700]	train-rmse:0.11055	eval-rmse:0.16219
# [1800]	train-rmse:0.10905	eval-rmse:0.16199
# [1900]	train-rmse:0.10745	eval-rmse:0.16178
# [2000]	train-rmse:0.10592	eval-rmse:0.16167
# [2100]	train-rmse:0.10458	eval-rmse:0.16149
# [2200]	train-rmse:0.10311	eval-rmse:0.16113
# [2300]	train-rmse:0.10175	eval-rmse:0.16089
# [2400]	train-rmse:0.10048	eval-rmse:0.16064
# [2500]	train-rmse:0.09904	eval-rmse:0.16049
# [2600]	train-rmse:0.09749	eval-rmse:0.16036
# [2700]	train-rmse:0.09635	eval-rmse:0.16025
# [2800]	train-rmse:0.09524	eval-rmse:0.16019
# [2900]	train-rmse:0.09415	eval-rmse:0.16009
# [3000]	train-rmse:0.09292	eval-rmse:0.15999
# [3100]	train-rmse:0.09149	eval-rmse:0.15985
# [3200]	train-rmse:0.09017	eval-rmse:0.15967
# [3300]	train-rmse:0.08900	eval-rmse:0.15957
# [3400]	train-rmse:0.08789	eval-rmse:0.15949
# [3500]	train-rmse:0.08643	eval-rmse:0.15940
# [3600]	train-rmse:0.08518	eval-rmse:0.15942
# [3616]	train-rmse:0.08505	eval-rmse:0.15943
# [0]	train-rmse:0.52198	eval-rmse:0.52906
# [100]	train-rmse:0.30140	eval-rmse:0.30932
# [200]	train-rmse:0.20849	eval-rmse:0.22119
# [300]	train-rmse:0.16924	eval-rmse:0.18683
# [400]	train-rmse:0.15023	eval-rmse:0.17264
# [500]	train-rmse:0.14040	eval-rmse:0.16622
# [600]	train-rmse:0.13445	eval-rmse:0.16269
# [700]	train-rmse:0.13075	eval-rmse:0.16068
# [800]	train-rmse:0.12784	eval-rmse:0.15935
# [900]	train-rmse:0.12465	eval-rmse:0.15827
# [1000]	train-rmse:0.12196	eval-rmse:0.15748
# [1100]	train-rmse:0.11984	eval-rmse:0.15705
# [1200]	train-rmse:0.11798	eval-rmse:0.15680
# [1300]	train-rmse:0.11617	eval-rmse:0.15672
# [1400]	train-rmse:0.11419	eval-rmse:0.15662
# [1500]	train-rmse:0.11233	eval-rmse:0.15644
# [1600]	train-rmse:0.11054	eval-rmse:0.15642
# [1700]	train-rmse:0.10887	eval-rmse:0.15636
# [1800]	train-rmse:0.10695	eval-rmse:0.15629
# [1900]	train-rmse:0.10537	eval-rmse:0.15627
# [2000]	train-rmse:0.10380	eval-rmse:0.15633
# [2011]	train-rmse:0.10364	eval-rmse:0.15632
# [0]	train-rmse:0.52394	eval-rmse:0.52117
# [100]	train-rmse:0.30210	eval-rmse:0.30529
# [200]	train-rmse:0.20745	eval-rmse:0.22092
# [300]	train-rmse:0.16773	eval-rmse:0.19045
# [400]	train-rmse:0.14866	eval-rmse:0.17843
# [500]	train-rmse:0.13849	eval-rmse:0.17323
# [600]	train-rmse:0.13262	eval-rmse:0.17047
# [700]	train-rmse:0.12914	eval-rmse:0.16897
# [800]	train-rmse:0.12649	eval-rmse:0.16811
# [900]	train-rmse:0.12375	eval-rmse:0.16736
# [1000]	train-rmse:0.12100	eval-rmse:0.16665
# [1100]	train-rmse:0.11849	eval-rmse:0.16617
# [1200]	train-rmse:0.11640	eval-rmse:0.16581
# [1300]	train-rmse:0.11457	eval-rmse:0.16543
# [1400]	train-rmse:0.11280	eval-rmse:0.16513
# [1500]	train-rmse:0.11108	eval-rmse:0.16491
# [1600]	train-rmse:0.10930	eval-rmse:0.16469
# [1700]	train-rmse:0.10763	eval-rmse:0.16451
# [1800]	train-rmse:0.10629	eval-rmse:0.16428
# [1900]	train-rmse:0.10492	eval-rmse:0.16404
# [2000]	train-rmse:0.10351	eval-rmse:0.16392
# [2100]	train-rmse:0.10230	eval-rmse:0.16379
# [2200]	train-rmse:0.10091	eval-rmse:0.16369
# [2300]	train-rmse:0.09942	eval-rmse:0.16360
# [2400]	train-rmse:0.09788	eval-rmse:0.16351
# [2500]	train-rmse:0.09637	eval-rmse:0.16348
# [2600]	train-rmse:0.09460	eval-rmse:0.16337
# [2700]	train-rmse:0.09317	eval-rmse:0.16337
# [2710]	train-rmse:0.09301	eval-rmse:0.16336
# [0]	train-rmse:0.52425	eval-rmse:0.51998
# [100]	train-rmse:0.30244	eval-rmse:0.30591
# [200]	train-rmse:0.20947	eval-rmse:0.22078
# [300]	train-rmse:0.16995	eval-rmse:0.18799
# [400]	train-rmse:0.15102	eval-rmse:0.17409
# [500]	train-rmse:0.14082	eval-rmse:0.16791
# [600]	train-rmse:0.13497	eval-rmse:0.16498
# [700]	train-rmse:0.13106	eval-rmse:0.16325
# [800]	train-rmse:0.12811	eval-rmse:0.16191
# [900]	train-rmse:0.12545	eval-rmse:0.16106
# [1000]	train-rmse:0.12269	eval-rmse:0.16039
# [1100]	train-rmse:0.12081	eval-rmse:0.16004
# [1200]	train-rmse:0.11857	eval-rmse:0.15963
# [1300]	train-rmse:0.11636	eval-rmse:0.15915
# [1400]	train-rmse:0.11439	eval-rmse:0.15882
# [1500]	train-rmse:0.11273	eval-rmse:0.15864
# [1600]	train-rmse:0.11102	eval-rmse:0.15840
# [1700]	train-rmse:0.10936	eval-rmse:0.15821
# [1800]	train-rmse:0.10792	eval-rmse:0.15811
# [1900]	train-rmse:0.10652	eval-rmse:0.15793
# [2000]	train-rmse:0.10514	eval-rmse:0.15790
# [2100]	train-rmse:0.10373	eval-rmse:0.15782
# [2200]	train-rmse:0.10232	eval-rmse:0.15776
# [2300]	train-rmse:0.10090	eval-rmse:0.15764
# [2400]	train-rmse:0.09975	eval-rmse:0.15765
# [2443]	train-rmse:0.09914	eval-rmse:0.15766
# [0]	train-rmse:0.52195	eval-rmse:0.52915
# [100]	train-rmse:0.30029	eval-rmse:0.31556
# [200]	train-rmse:0.20698	eval-rmse:0.23027
# [300]	train-rmse:0.16771	eval-rmse:0.19699
# [400]	train-rmse:0.14876	eval-rmse:0.18282
# [500]	train-rmse:0.13894	eval-rmse:0.17690
# [600]	train-rmse:0.13346	eval-rmse:0.17436
# [700]	train-rmse:0.12980	eval-rmse:0.17291
# [800]	train-rmse:0.12687	eval-rmse:0.17199
# [900]	train-rmse:0.12461	eval-rmse:0.17134
# [1000]	train-rmse:0.12257	eval-rmse:0.17075
# [1100]	train-rmse:0.12062	eval-rmse:0.17027
# [1200]	train-rmse:0.11862	eval-rmse:0.16973
# [1300]	train-rmse:0.11678	eval-rmse:0.16923
# [1400]	train-rmse:0.11500	eval-rmse:0.16886
# [1500]	train-rmse:0.11302	eval-rmse:0.16849
# [1600]	train-rmse:0.11126	eval-rmse:0.16818
# [1700]	train-rmse:0.10946	eval-rmse:0.16779
# [1800]	train-rmse:0.10797	eval-rmse:0.16754
# [1900]	train-rmse:0.10649	eval-rmse:0.16730
# [2000]	train-rmse:0.10480	eval-rmse:0.16707
# [2100]	train-rmse:0.10344	eval-rmse:0.16691
# [2200]	train-rmse:0.10220	eval-rmse:0.16676
# [2300]	train-rmse:0.10092	eval-rmse:0.16673
# [2400]	train-rmse:0.09964	eval-rmse:0.16669
# [2500]	train-rmse:0.09802	eval-rmse:0.16658
# [2578]	train-rmse:0.09723	eval-rmse:0.16660
# 0.16071551851864402

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor(n_estimators=300, random_state=2019, max_depth=15, n_jobs=-1).fit(df_train, y_reg)

# %%
print('RandomForest rmse:', cv_rmse(rf_reg).mean())
# Out:
# RandomForest rmse: 0.17580169634521361

# %%
# plot the feature importance
feature_importance_df_rf = pd.Series(data=rf_reg.feature_importances_, index=df_train.columns).sort_values(ascending=False)
fig, ax = plt.subplots(figsize=(12,15), nrows=1, ncols=1)
sns.barplot(x=feature_importance_df_rf, y=feature_importance_df_rf.index, ax=ax)
# Out:
# <Axes: xlabel='None', ylabel='None'>

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

svr_reg = make_pipeline(StandardScaler(), SVR(C=3.5)).fit(df_train, y_reg)

# %%
import sys
print(sys.version)
# Out:
# 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]

# %%
print('Support Vector Regressor rmse :', cv_rmse(svr_reg).mean())
# Out:
# Support Vector Regressor rmse : 0.18570616705482715

# %%
from sklearn.tree import ExtraTreeRegressor

extra_tree_reg = ExtraTreeRegressor(
    criterion='squared_error', 
    max_depth=15, 
    min_samples_leaf=10, 
    min_samples_split=10,
    random_state=2019
).fit(df_train, y_reg)

# %%
print('ExtraTreeRegressor rmse :', cv_rmse(extra_tree_reg).mean())
# Out:
# ExtraTreeRegressor rmse : 0.22611389019455883

# %%
# 두 종류의 모델이 필요하다.
# 하나는 지금까지 학습시킨 개별적인 기본모델들이고,
# 다른 하나는 개별 기반 모델의 예측 데이터를 학습데이터로 만들어서 학습하는 최종 메타 모델이다.

# 개별 기반 모델에서 최종 메타 모델이 사용할 학습 및 테스트용 데이터를 생성하기 위한 함수
def get_stacking_base_datasets(model, X_train_n, y_train_n, X_test_n):
    # KFold는 위에서 만들어진것을 쓴다.
    # 추후에 메타 모델이 학습 데이터 반환을 위한 넘파이 배열 초기화
    train_fold_pred = np.zeros((df_train.shape[0], 1))
    test_pred = np.zeros((df_test.shape[0], folds.n_splits))
    print(model.__class__.__name__, ' model 시작')
    
    for folds_, (trn_index, val_index) in enumerate(folds.split(X_train_n)):
        # 입력된 학습 데이터에서 기반 모델이 학습/예측할 폴드 데이터 세트 추출
        print('\t폴드 세트: ', folds_, ' 시작')
        trn_data = X_train_n.iloc[trn_index]
        val_data = X_train_n.iloc[val_index]
        y_trn = y_train_n.iloc[trn_index]
        
        # 폴드 세트 내부에서 다시 만들어진 학습 데이터로 기반 모델의 학습 수행
        model.fit(trn_data, y_trn)
        # 폴드 세트 내부에서 다시 만들어진 검증 데이터로 기반 모델 예측 후 데이터 저장
        train_fold_pred[val_index,:] = model.predict(val_data).reshape(-1,1)
        # 입력된 원본 테스트 데이터를 폴드 세트 내 학습된 기반 모델에서 예측 후 데이터 저장
        test_pred[:, folds_] = model.predict(X_test_n)
        
    # 폴드 세트 내에서 원본 테스트 데이터를 예측한 데이터를 평균하여 테스트 데이터로 생성
    test_pred_mean = np.mean(test_pred, axis=1)
    
    # train_fold_predsms 최종 메타 모델이 사용하는 학습 데이터, test_pred_mean은 테스트 데이터
    return train_fold_pred, test_pred_mean

# %%
# xgboost와 lightgbm은 각각 oof1,oof2 | predictions, predictions2 로 만들어져 있으니 RandomForest와 SVR, ExtraTree 모델들만 구해본다.
rf_train, rf_test = get_stacking_base_datasets(rf_reg, df_train, y_reg, df_test)
svr_train, svr_test = get_stacking_base_datasets(svr_reg, df_train, y_reg, df_test)
extra_train, extra_test = get_stacking_base_datasets(extra_tree_reg, df_train, y_reg, df_test)

# xgboost와 lightgbm의 앙상블도 준비해보자.
# 비율은 0.4*xgb + 0.6*lgb
oof3 = 0.6 * oof1 + 0.4 * oof2
predictions3 = 0.6 * predictions + 0.4 * predictions2
# Out:
# RandomForestRegressor  model 시작
# 	폴드 세트:  0  시작
# 	폴드 세트:  1  시작
# 	폴드 세트:  2  시작
# 	폴드 세트:  3  시작
# 	폴드 세트:  4  시작
# Pipeline  model 시작
# 	폴드 세트:  0  시작
# 	폴드 세트:  1  시작
# 	폴드 세트:  2  시작
# 	폴드 세트:  3  시작
# 	폴드 세트:  4  시작
# ExtraTreeRegressor  model 시작
# 	폴드 세트:  0  시작
# 	폴드 세트:  1  시작
# 	폴드 세트:  2  시작
# 	폴드 세트:  3  시작
# 	폴드 세트:  4  시작

# %%
# 먼저 모델링 전 데이터들을 퍼셉트론이 가장 잘 학습할 수 있도록 정규화 해주도록 하자.
from sklearn.preprocessing import StandardScaler

x_scaler = StandardScaler().fit(df_train)
y_scaler = StandardScaler().fit(y_reg.values.reshape(-1,1))

x_train = x_scaler.transform(df_train)
x_test = x_scaler.transform(df_test)
y_train = y_scaler.transform(y_reg.values.reshape(-1,1))

# %%
oof_percep = np.zeros(len(x_train))
prediction_percep = np.zeros(len(x_test))

oof_percep = y_scaler.inverse_transform(oof_percep)
prediction_percep = y_scaler.inverse_transform(prediction_percep)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\dudnj\ws\aiffel\ex1.ipynb Cell 61 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y125sZmlsZQ%3D%3D?line=0'>1</a> oof_percep = np.zeros(len(x_train))
#       <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y125sZmlsZQ%3D%3D?line=1'>2</a> prediction_percep = np.zeros(len(x_test))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y125sZmlsZQ%3D%3D?line=3'>4</a> oof_percep = y_scaler.inverse_transform(oof_percep)
#       <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y125sZmlsZQ%3D%3D?line=4'>5</a> prediction_percep = y_scaler.inverse_transform(prediction_percep)
#
# File c:\Users\dudnj\.conda\envs\aiffel\lib\site-packages\sklearn\preprocessing\_data.py:1048, in StandardScaler.inverse_transform(self, X, copy)
#    1045 check_is_fitted(self)
#    1047 copy = copy if copy is not None else self.copy
# -> 1048 X = check_array(
#    1049     X,
#    1050     accept_sparse="csr",
#    1051     copy=copy,
#    1052     dtype=FLOAT_DTYPES,
#    1053     force_all_finite="allow-nan",
#    1054 )
#    1056 if sparse.issparse(X):
#    1057     if self.with_mean:
#
# File c:\Users\dudnj\.conda\envs\aiffel\lib\site-packages\sklearn\utils\validation.py:938, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     936     # If input is 1D raise error
#     937     if array.ndim == 1:
# --> 938         raise ValueError(
#     939             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     940             "Reshape your data either using array.reshape(-1, 1) if "
#     941             "your data has a single feature or array.reshape(1, -1) "
#     942             "if it contains a single sample.".format(array)
#     943         )
#     945 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#     946     raise ValueError(
#     947         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     948         "Convert your data to numeric values explicitly instead."
#     949     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0. 0. 0. ... 0. 0. 0.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
from sklearn.linear_model import Ridge

# 개별 모델이 반환한 테스트용 데이터 세트를 스태킹 형태로 결합
## 스택모델1 : 랜덤포레스트, XGB, LGB, SVR, 엑스트라 랜더마이즈 트리
# Stack_final_X_train = np.concatenate([rf_train, oof1.reshape(-1,1), oof2.reshape(-1,1), svr_train, extra_train], axis=1)
# Stack_final_X_test = np.concatenate([rf_test[:,np.newaxis], predictions[:,np.newaxis], predictions2[:,np.newaxis],
#                                     svr_test[:,np.newaxis], extra_test[:,np.newaxis]], axis=1)

## 스택모델2 : 랜덤포레스트, XGB, LGB, 0.6*LGB+0.4*XGB
# Stack_final_X_train = np.concatenate([rf_train, oof1.reshape(-1,1), oof2.reshape(-1,1), oof3.reshape(-1,1)], axis=1)
# Stack_final_X_test = np.concatenate([rf_test[:,np.newaxis], predictions[:,np.newaxis], predictions2[:,np.newaxis], predictions3[:,np.newaxis]], axis=1)

## 스택모델3 : 다층 퍼셉트론, XGB, LGB, SVR, 엑스트라 랜더마이즈 트리
# Stack_final_X_train = np.concatenate([oof_percep.reshape(-1,1), rf_train, oof1.reshape(-1,1), oof2.reshape(-1,1), svr_train, extra_train], axis=1)
# Stack_final_X_test = np.concatenate([prediction_percep[:,np.newaxis], rf_test[:,np.newaxis], predictions[:,np.newaxis], predictions2[:,np.newaxis],
#                                     svr_test[:,np.newaxis], extra_test[:,np.newaxis]], axis=1)

## 스택모델4 : 다층 퍼셉트론, XGB, LGB, SVR, 엑스트라 랜더마이즈 트리
Stack_final_X_train = np.concatenate([oof_percep.reshape(-1,1), rf_train, oof1.reshape(-1,1), oof2.reshape(-1,1), svr_train, extra_train], axis=1)
Stack_final_X_test = np.concatenate([prediction_percep[:,np.newaxis], rf_test[:,np.newaxis], predictions[:,np.newaxis], predictions2[:,np.newaxis],
                                    svr_test[:,np.newaxis], extra_test[:,np.newaxis]], axis=1)


# 최종 메타 모델은 릿지 모델을 적용
meta_model_ridge = Ridge(alpha=0.1)

# 개별 모델 예측값을 기반으로 새롭게 만들어진 학습/테스트 데이터로 메타 모델 예측
meta_model_ridge.fit(Stack_final_X_train, y_reg)
final = meta_model_ridge.predict(Stack_final_X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\dudnj\ws\aiffel\ex1.ipynb Cell 65 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y113sZmlsZQ%3D%3D?line=2'>3</a> # 개별 모델이 반환한 테스트용 데이터 세트를 스태킹 형태로 결합
#       <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y113sZmlsZQ%3D%3D?line=3'>4</a> ## 스택모델1 : 랜덤포레스트, XGB, LGB, SVR, 엑스트라 랜더마이즈 트리
#       <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y113sZmlsZQ%3D%3D?line=4'>5</a> # Stack_final_X_train = np.concatenate([rf_train, oof1.reshape(-1,1), oof2.reshape(-1,1), svr_train, extra_train], axis=1)
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y113sZmlsZQ%3D%3D?line=16'>17</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y113sZmlsZQ%3D%3D?line=17'>18</a> ## 스택모델4 : 다층 퍼셉트론, XGB, LGB, SVR, 엑스트라 랜더마이즈 트리
#      <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y113sZmlsZQ%3D%3D?line=18'>19</a> Stack_final_X_train = np.concatenate([oof_percep.reshape(-1,1), rf_train, oof1.reshape(-1,1), oof2.reshape(-1,1), svr_train, extra_train], axis=1)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y113sZmlsZQ%3D%3D?line=19'>20</a> Stack_final_X_test = np.concatenate([prediction_percep[:,np.newaxis], rf_test[:,np.newaxis], predictions[:,np.newaxis], predictions2[:,np.newaxis],
#      <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y113sZmlsZQ%3D%3D?line=20'>21</a>                                     svr_test[:,np.newaxis], extra_test[:,np.newaxis]], axis=1)
#      <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y113sZmlsZQ%3D%3D?line=23'>24</a> # 최종 메타 모델은 릿지 모델을 적용
#      <a href='vscode-notebook-cell:/c%3A/Users/dudnj/ws/aiffel/ex1.ipynb#Y113sZmlsZQ%3D%3D?line=24'>25</a> meta_model_ridge = Ridge(alpha=0.1)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 3 dimension(s) and the array at index 1 has 2 dimension(s)

# %%
# test_ridge_preds = np.expm1(ridge_model2.predict(df_test))
# test_rf_preds = np.expm1(rf_reg.predict(df_test))
# test_lgb_preds = np.expm1(predictions)
# test_xgb_preds = np.expm1(predictions2)
# rest_ensemble_preds = 0.6*test_lgb_preds + 0.4*test_xgb_preds
# percep_inv_model_preds = np.expm1(y_scaler.inverse_transform(percep_model_preds))

stack_preds = np.expm1(final)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/588831524.py in <module>
#       6 # percep_inv_model_preds = np.expm1(y_scaler.inverse_transform(percep_model_preds))
#       7
# ----> 8 stack_preds = np.expm1(final)
#
# NameError: name 'final' is not defined

# %%
# 스택모델 : 다층 퍼셉트론, 랜덤포레스트, XGB, LGB, ExtraTree
submission0 = pd.DataFrame({'id': test_id, 'price' : stack_preds})
submission0.to_csv('./submission.csv', index=False)
print('끝!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/980456732.py in <module>
#       1 # 스택모델 : 다층 퍼셉트론, 랜덤포레스트, XGB, LGB, ExtraTree
# ----> 2 submission0 = pd.DataFrame({'id': test_id, 'price' : stack_preds})
#       3 submission0.to_csv('./submission.csv', index=False)
#       4 print('끝!')
#
# NameError: name 'stack_preds' is not defined
